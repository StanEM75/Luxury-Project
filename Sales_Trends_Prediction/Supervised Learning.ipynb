# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import RFE
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score,balanced_accuracy_score
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import VotingClassifier
import requests
import random
import joblib

# %%
df = pd.read_csv('df.csv')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %% [markdown]
# ## Main objective of the model

# %% [markdown]
# We want to predict the number of sales depending on many parameters.
#
# At the end, the user should be able to predict the number of sales by selecting values for every feature.

# %%
df
# Out:
#        Location   id  Sales      Channel  MonthYear          Brand Category  \
# 0       Beijing  3.0    1.0    Own Store     201401  Louis Vuitton  Handbag
# 1       Beijing  3.0    0.0      Partner     201401  Louis Vuitton  Handbag
# 2        London  3.0    1.0      Partner     201401  Louis Vuitton  Handbag
# 3      New York  3.0    2.0      Partner     201401  Louis Vuitton  Handbag
# 4        Online  3.0   15.0  Application     201401  Louis Vuitton  Handbag
# ...         ...  ...    ...          ...        ...            ...      ...
# 16350     Paris  4.0    2.0    Own Store     202412  Louis Vuitton   Wallet
# 16351     Paris  4.0    1.0      Partner     202412  Louis Vuitton   Wallet
# 16352      Rome  4.0    0.0    Own Store     202412  Louis Vuitton   Wallet
# 16353     Tokyo  4.0    1.0    Own Store     202412  Louis Vuitton   Wallet
# 16354     Tokyo  4.0    1.0      Partner     202412  Louis Vuitton   Wallet
#
#          Trend
# 0      Unknown
# 1      Unknown
# 2      Unknown
# 3      Unknown
# 4      Neutral
# ...        ...
# 16350  Unknown
# 16351  Unknown
# 16352  Unknown
# 16353  Unknown
# 16354  Unknown
#
# [16355 rows x 8 columns]

# %% [markdown]
# ## Encode the text columns to categories columns

# %%
label_encoder = LabelEncoder()

# %%
to_encode = ['Location', 'Channel', 'Brand',
       'Category','Trend']

# %%
for column in to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# %% [markdown]
# ## Scale data

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %% [markdown]
# ## Split into train & test sets

# %%
X=df.drop(columns=['Sales'])
y=df['Sales']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=123)

# %% [markdown]
# ## First model : Linear Regression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Mean Squared Error: 38.818750782035075
# R^2 Score: 0.11353079621195805
# Coefficients: [-7.59209207e-02 -3.82598707e-02  3.65404330e-01  5.82896020e-04
#  -1.09528614e-01 -5.86137007e-01 -2.35016919e+00]
# Intercept: -107.27996285905267

# %% [markdown]
# ## Second Model: Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_pred = ridge_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

print("Coefficients:", ridge_model.coef_)
print("Intercept:", ridge_model.intercept_)
# Out:
# Mean Squared Error: 38.81872734262166
# R^2 Score: 0.11353133147694539
# Coefficients: [-7.59320302e-02 -3.82636988e-02  3.65378052e-01  5.82842092e-04
#  -1.09535961e-01 -5.86042097e-01 -2.34994708e+00]
# Intercept: -107.2695415278159
